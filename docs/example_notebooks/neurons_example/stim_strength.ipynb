# %% [markdown]
# # Neurons example with nominal stim strengths
# ## Generate some data

# %%
from bayes_window import models, fake_spikes_explore, BayesWindow
from bayes_window.generative_models import generate_spikes_stim_strength, generate_fake_spikes
from importlib import reload
import numpy as np
import altair as alt

# %%
df0=generate_fake_spikes(mouse_response_slope=2,
                                   n_trials=20,
                                   n_neurons=6,
                                   n_mice=3,
                                   dur=5,
                         slowest_fr=3,
                                   overall_stim_response_strength=5
                     )[0]

# %%
BayesWindow(df0, 'isi', treatment='stim', condition='neuron', group='mouse', detail='i_trial').data_box_detail()
# Out:
# alt.FacetChart(...)

# %%
df = generate_spikes_stim_strength(overall_stim_response_strengths=np.arange(1, 12),

                                   n_trials=20,
                                   n_neurons=6,
                                   n_mice=3,
                                   dur=5,
                         slowest_fr=3,
                                   mouse_response_slope=2)

#%

window = BayesWindow(df, 'isi', treatment='stim_strength', condition='neuron', group='mouse', detail='i_trial')
window.data_box_detail()
# Out:
# alt.FacetChart(...)

# %%
window = BayesWindow(df, 'isi', treatment='stim_strength', condition='neuron_x_mouse', group='mouse', detail='i_trial')
window.fit_slopes(do_make_change=False, dist_y='gamma', progress_bar=True)
window.chart
# Out:
# ...
# warmup:  18%|█▊        | 211/1200 [01:29<10:55,  1.51it/s, 1023 steps of size 1.69e-03. acc. prob=0.96]

# %%
window.posterior['slope_per_condition']

# %%
'alt'
